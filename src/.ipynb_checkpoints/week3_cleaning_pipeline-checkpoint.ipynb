# %%
import sys
sys.path.append('C:/SupplyChainAssistant/src')
from pipeline import run_pipeline

print("Pipeline imported successfully!")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 import sys
#       2 sys.path.append('C:/SupplyChainAssistant/src')
# ----> 3 from pipeline import run_pipeline
#       5 print("Pipeline imported successfully!")
#
# ImportError: cannot import name 'run_pipeline' from 'pipeline' (C:\SupplyChainAssistant\src\pipeline.py)
